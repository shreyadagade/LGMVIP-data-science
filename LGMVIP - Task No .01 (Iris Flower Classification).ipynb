# %% [markdown]
# # Lets GrowMore Virtual Internship JANUARY - 2022

# %% [markdown]
# # Name :- Shreya  Dattatray Dagade

# %% [markdown]
# # Domain :- Data Science

# %% [markdown]
# # Task No 01 :-  Iris Flowers classification ML Project

# %% [markdown]
# # Task Description :-
#                      Iris flower classification is a very popular machine learning poject. The Iris classification contains three classes Versicolor, Setosa, Virginica. The aim of the iris flower classification is to predict flowers based on their specific features.

# %% [markdown]
# # Dataset link :-  http://archive.ics.uci.edu/ml/datasets/Iris

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %% [markdown]
# #  Load the data

# %%
df = pd.read_csv("C:/Users/Admin/Downloads/iris_flowers.csv")

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', ' petal_width', 'class'], dtype='object')

# %%
#Display first five rows of the dataset
df.head()
# Out:
#    sepal_length  sepal_width  petal_length   petal_width        class
# 0           5.1          3.5           1.4           0.2  iris_setosa
# 1           4.9          3.0           1.4           0.2  iris_setosa
# 2           4.7          3.2           1.3           0.2  iris_setosa
# 3           4.6          3.1           1.5           0.2  iris_setosa
# 4           5.0          3.6           1.4           0.2  iris_setosa

# %%
# Display last five rows of the dataset
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length   petal_width           class
# 145           6.7          3.0           5.2           2.3  iris_virginica
# 146           6.3          2.5           5.0           1.9  iris_virginica
# 147           6.5          3.0           5.2           2.0  iris_virginica
# 148           6.2          3.4           5.4           2.3  iris_virginica
# 149           5.9          3.0           5.1           1.8  iris_virginica

# %%
# Display stats  about data
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length   petal_width
# count    150.000000   150.000000    150.000000    150.000000
# mean       5.843333     3.054000      3.758667      1.198667
# std        0.828066     0.433594      1.764420      0.763161
# min        4.300000     2.000000      1.000000      0.100000
# 25%        5.100000     2.800000      1.600000      0.300000
# 50%        5.800000     3.000000      4.350000      1.300000
# 75%        6.400000     3.300000      5.100000      1.800000
# max        7.900000     4.400000      6.900000      2.500000

# %%
# To display basic info about datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3    petal_width  150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# To display no. of samples of each class
df['class'].value_counts()
# Out:
# iris_setosa        50
# iris_versicolor    50
# iris_virginica     50
# Name: class, dtype: int64

# %%
df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length   petal_width            class
# 114           5.8          2.8           5.1           2.4   iris_virginica
# 69            5.6          2.5           3.9           1.1  iris_versicolor
# 129           7.2          3.0           5.8           1.6   iris_virginica
# 116           6.5          3.0           5.5           1.8   iris_virginica
# 109           7.2          3.6           6.1           2.5   iris_virginica
# 75            6.6          3.0           4.4           1.4  iris_versicolor
# 100           6.3          3.3           6.0           2.5   iris_virginica
# 57            4.9          2.4           3.3           1.0  iris_versicolor
# 96            5.7          2.9           4.2           1.3  iris_versicolor
# 52            6.9          3.1           4.9           1.5  iris_versicolor

# %% [markdown]
# # Preprocessing the dataset

# %%
# check for null values
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
#  petal_width    0
# class           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', ' petal_width', 'class'], dtype='object')

# %%
# return number of unique elements in the object
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
#  petal_width    22
# class            3
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
#histograms
df['sepal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
df['sepal_width'].hist()
# Out:
# <AxesSubplot:>

# %%
df['petal_length'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='class',y='petal_length',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='class',y='sepal_length',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='class',y='sepal_width',data=df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal_width'>

# %% [markdown]
# # Seperate features and target

# %%
data = df.values
X = data[:,0:4]
Y = data[:,4]

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.0, 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3.0, 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.0, 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5.0, 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.0, 3.3, 1.4, 0.2],
#        [7.0, 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4.0, 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1.0],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.0, 2.0, 3.5, 1.0],
#        [5.9, 3.0, 4.2, 1.5],
#        [6.0, 2.2, 4.0, 1.0],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3.0, 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1.0],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4.0, 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3.0, 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3.0, 5.0, 1.7],
#        [6.0, 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1.0],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1.0],
#        [5.8, 2.7, 3.9, 1.2],
#        [6.0, 2.7, 5.1, 1.6],
#        [5.4, 3.0, 4.5, 1.5],
#        [6.0, 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3.0, 4.1, 1.3],
#        [5.5, 2.5, 4.0, 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3.0, 4.6, 1.4],
#        [5.8, 2.6, 4.0, 1.2],
#        [5.0, 2.3, 3.3, 1.0],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3.0, 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3.0, 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6.0, 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3.0, 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3.0, 5.8, 2.2],
#        [7.6, 3.0, 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2.0],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3.0, 5.5, 2.1],
#        [5.7, 2.5, 5.0, 2.0],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3.0, 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6.0, 2.2, 5.0, 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2.0],
#        [7.7, 2.8, 6.7, 2.0],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6.0, 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3.0, 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3.0, 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2.0],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3.0, 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.0, 3.0, 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3.0, 5.2, 2.3],
#        [6.3, 2.5, 5.0, 1.9],
#        [6.5, 3.0, 5.2, 2.0],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3.0, 5.1, 1.8]], dtype=object)

# %%
Y
# Out:
# array(['iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_setosa', 'iris_setosa',
#        'iris_setosa', 'iris_setosa', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_versicolor', 'iris_versicolor', 'iris_versicolor',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica', 'iris_virginica',
#        'iris_virginica', 'iris_virginica'], dtype=object)

# %% [markdown]
# # Split the dataset into train & test

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['class'], axis=1)
y = df['class']
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
train, test = train_test_split(df, test_size = 0.25)
print(train.shape)
print(test.shape)
# Out:
# (112, 5)
# (38, 5)

# %% [markdown]
# # Support vector machine algorithm

# %%
from sklearn.svm import SVC
svn = SVC()
svn.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # Checking for Ouliars

# %%
import matplotlib.pyplot as plt
plt.figure(1)
plt.boxplot([df['sepal_length']])
plt.figure(2)
plt.boxplot([df['sepal_width']])
plt.show()

# %% [markdown]
# # Plotting a Pie Diagram

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
s = [50,50,50]
ax.pie(s, labels = l,autopct='%1.2f%%')
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# # Plotting a Histogram

# %%
df.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(kind ='density',subplots = True, layout =(3,3),sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
corr_mat = df.corr()
corr_mat
# Out:
#               sepal_length  sepal_width  petal_length   petal_width
# sepal_length      1.000000    -0.109369      0.871754      0.817954
# sepal_width      -0.109369     1.000000     -0.420516     -0.356544
# petal_length      0.871754    -0.420516      1.000000      0.962757
#  petal_width      0.817954    -0.356544      0.962757      1.000000

# %%
X_train = train[['sepal_length', 'sepal_width', 'petal_length']]

X_test = test[['sepal_length', 'sepal_width', 'petal_length']]

# %%
X_train.head()
# Out:
#      sepal_length  sepal_width  petal_length
# 30            4.8          3.1           1.6
# 15            5.7          4.4           1.5
# 42            4.4          3.2           1.3
# 104           6.5          3.0           5.8
# 10            5.4          3.7           1.5

# %%
y_test.head()
# Out:
# 24        iris_setosa
# 70    iris_versicolor
# 62    iris_versicolor
# 64    iris_versicolor
# 28        iris_setosa
# Name: class, dtype: object

# %% [markdown]
# # Visualization

# %%
sns.boxplot(x="class", y='sepal_width', data= df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal_width'>

# %%
sns.boxplot(x="class", y='sepal_length', data= df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal_length'>

# %%
sns.boxplot(x="class", y='petal_length', data= df)
# Out:
# <AxesSubplot:xlabel='class', ylabel='petal_length'>

# %%
sns.pairplot(df,hue = 'class')

# %% [markdown]
# # Correlation matrix

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True, cmap="seismic")
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_reg.score(X_train, y_train)
# Out:
# 0.9642857142857143

# %%
log_reg.score(X, y)
# Out:
# 0.96

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %% [markdown]
# # Accuracy of model

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.svm import SVC
model = SVC(gamma='auto')
model.fit(X_train, y_train)
prediction = model.predict(X_test)
print(f'Accuracy of Model: {accuracy_score(y_test, prediction)}')
print(f'Report of Model: \n {classification_report(y_test, prediction)}')
# Out:
# Accuracy of Model: 0.9473684210526315
# Report of Model:
#                   precision    recall  f1-score   support
#
#     iris_setosa       1.00      1.00      1.00        12
# iris_versicolor       0.90      0.90      0.90        10
#  iris_virginica       0.94      0.94      0.94        16
#
#        accuracy                           0.95        38
#       macro avg       0.95      0.95      0.95        38
#    weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# # Label encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['class'] = le.fit_transform(df['class'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length   petal_width  class
# 0           5.1          3.5           1.4           0.2      0
# 1           4.9          3.0           1.4           0.2      0
# 2           4.7          3.2           1.3           0.2      0
# 3           4.6          3.1           1.5           0.2      0
# 4           5.0          3.6           1.4           0.2      0

# %%
#drop column
X= df.drop(columns=['class'])
y= df['class']
X[:5]
# Out:
#    sepal_length  sepal_width  petal_length   petal_width
# 0           5.1          3.5           1.4           0.2
# 1           4.9          3.0           1.4           0.2
# 2           4.7          3.2           1.3           0.2
# 3           4.6          3.1           1.5           0.2
# 4           5.0          3.6           1.4           0.2

# %%
y[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %% [markdown]
# #                                        Thank You!
